# %% [markdown]
# # Experiment: Train Linear Support Vector Machine with TF-IDF Features

# %% [markdown]
# ## Confirm Environment

# %%
# !conda info
# Out:
#      active environment : northeastern
#     active env location : /home/curtis/anaconda3/envs/northeastern
#             shell level : 2
#        user config file : /home/curtis/.condarc
#  populated config files : /home/curtis/anaconda3/.condarc
#           conda version : 24.9.2
#     conda-build version : 24.9.0
#          python version : 3.12.7.final.0
#                  solver : libmamba (default)
#        virtual packages : __archspec=1=skylake
#                           __conda=24.9.2=0
#                           __glibc=2.39=0
#                           __linux=6.6.87.2=0
#                           __unix=0=0
#        base environment : /home/curtis/anaconda3  (writable)
#       conda av data dir : /home/curtis/anaconda3/etc/conda
#   conda av metadata url : None
#            channel URLs : https://repo.anaconda.com/pkgs/main/linux-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/linux-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#           package cache : /home/curtis/anaconda3/pkgs
#                           /home/curtis/.conda/pkgs
#        envs directories : /home/curtis/anaconda3/envs
#                           /home/curtis/.conda/envs
#                platform : linux-64
#              user-agent : conda/24.9.2 requests/2.32.3 CPython/3.12.7 Linux/6.6.87.2-microsoft-standard-WSL2 ubuntu/24.04.1 glibc/2.39 solver/libmamba conda-libmamba-solver/24.9.0 libmambapy/1.5.8 aau/0.4.4 c/. s/. e/.
#                 UID:GID : 1000:1000
#              netrc file : None
#            offline mode : False

# %% [markdown]
# ## Setup and Imports

# %%
from emolex.preprocessing import load_mental_health_sentiment_dataset, clean_text, encode_sentiment_labels, split_data, tfidf_text_vectorization
from emolex.ml_models import train_tfidf_svm_model
from emolex.evaluation import generate_confusion_matrix, generate_classification_report
# Out:
# 2025-07-02 15:25:34.434029: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-02 15:25:34.491055: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751484334.569159   46418 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751484334.590090   46418 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1751484334.628893   46418 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1751484334.628935   46418 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1751484334.628938   46418 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1751484334.628940   46418 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-07-02 15:25:34.642405: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [nltk_data] Downloading package wordnet to /home/curtis/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/curtis/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# ## Load Data

# %%
df = load_mental_health_sentiment_dataset()
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51093 entries, 0 to 51092
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    51093 non-null  object
#  1   label   51093 non-null  object
# dtypes: object(2)
# memory usage: 798.5+ KB
#                                                 text    label
# 0                                         oh my gosh  Anxiety
# 1  trouble sleeping, confused mind, restless hear...  Anxiety
# 2  All wrong, back off dear, forward doubt. Stay ...  Anxiety
# 3  I've shifted my focus to something else but I'...  Anxiety
# 4  I'm restless and restless, it's been a month n...  Anxiety

# %% [markdown]
# ## Clean Data

# %%
print(f"\n--- Cleaning Text ---")
df['clean_text'] = df["text"].apply(clean_text)
print("Text cleaning complete. Sample cleaned text:")
print("\n", df[["text", "clean_text"]].sample(5))
# Out:
# --- Cleaning Text ---
# Text cleaning complete. Sample cleaned text:
#
#                                                      text  \
# 11505  its impossible for me to feel good about who i...
# 21680  Writing right now cus I feel pretty horrible a...
# 23445  he told me that he has dreams a lot of me just...
# 37227  @nerdd I was pretty sure that you were checkin...
# 16113  I have been through some terrible things. I ha...
#
#                                               clean_text
# 11505  impossible feel good impossible ever comfortab...
# 21680  writing right cu feel pretty horrible needed w...
# 23445  told dream lot leaving something really got de...
# 37227  nerdd pretty sure checking new tweet iphone me...
# 16113  terrible thing put people terrible thing canno...

# %% [markdown]
# ## Encode Labels

# %%
print(f"\n--- Encoding Labels ---")
df, encoder = encode_sentiment_labels(df)
print("Label encoding complete. Sample encoded labels:")
print("\n", df[['label', 'label_encoded']].sample(5))
# Out:
# --- Encoding Labels ---
# Label Encoding Map: {'Anxiety': 0, 'Bipolar': 1, 'Depression': 2, 'Normal': 3, 'Personality disorder': 4, 'Stress': 5, 'Suicidal': 6}
# Label encoding complete. Sample encoded labels:
#
#              label  label_encoded
# 22266  Depression              2
# 39112  Depression              2
# 48866     Bipolar              1
# 6301       Normal              3
# 28495      Normal              3

# %% [markdown]
# ## Train-Test Split

# %%
print("\n--- Perform Train-Test Split ---")
X_train_raw, X_test_raw, y_train, y_test = split_data(df) 
print(f"Train set size: {len(X_train_raw)} samples")
print(f"Test set size: {len(X_test_raw)} samples")
# Out:
# --- Perform Train-Test Split ---
# Train set size: 40874 samples
# Test set size: 10219 samples

# %% [markdown]
# ## Vectorization

# %%
print("\n--- Compute TF-IDF Vectorization ---")
X_train_tfidf, X_test_tfidf, _ = tfidf_text_vectorization(X_train_raw, X_test_raw)
# Out:
# --- Compute TF-IDF Vectorization ---
# Starting TF-IDF feature extraction with max_features=10000...
# TF-IDF transformed X_train_tfidf shape: (40874, 10000)
# TF-IDF transformed X_test_tfidf shape: (10219, 10000)

# %% [markdown]
# ## Train Model

# %%
print("\n--- Train Model ---")
model = train_tfidf_svm_model(X_train_tfidf, y_train)
# Out:
# --- Train Model ---
# Training Linear SVM model...
# Linear SVM model training complete.

# %% [markdown]
# ## Evaluate Model

# %%
print("\n--- Predict Test Classes ---")
y_pred = model.predict(X_test_tfidf)
# Out:
# --- Predict Test Classes ---

# %%
print("\n--- Generate Confusion Matrix ---")
fig, ax = generate_confusion_matrix(y_test, y_pred, class_labels=encoder.classes_)
# Out:
# --- Generate Confusion Matrix ---
# /mnt/c/grad_school/northeastern/ie7500/project/NLP_Project/src/emolex/evaluation.py:77: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
print("\n--- Generate Classification Report ---")
generate_classification_report(y_test, y_pred, class_labels=encoder.classes_)
# Out:
# --- Generate Classification Report ---
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/envs/northeastern/lib/python3.10/site-packages/sklearn/utils/_encode.py:183, in _unique_python(values, return_inverse, return_counts)
#     181 uniques_set, missing_values = _extract_missing(uniques_set)
# --> 183 uniques = sorted(uniques_set)
#     184 uniques.extend(missing_values.to_list())
#
# TypeError: '<' not supported between instances of 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 print("\n--- Generate Classification Report ---")
# ----> 2 generate_classification_report(y_test, y_pred, class_labels=encoder.classes_)
#
# File /mnt/c/grad_school/northeastern/ie7500/project/NLP_Project/src/emolex/evaluation.py:97, in generate_classification_report(y_true, y_pred, class_labels)
#      80 def generate_classification_report(
#      81     y_true: np.ndarray | pd.Series,
#      82     y_pred: np.ndarray | pd.Series,
#      83     class_labels: list[str] = None
#      84 ) -> str:
#      85     """
#      86     Generates and prints a classification report.
#      87
#    (...)
#      95         str: The formatted classification report.
#      96     """
# ---> 97     report = classification_report(y_true, y_pred, labels=class_labels)
#      98     print(report)
#
# File ~/anaconda3/envs/northeastern/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~/anaconda3/envs/northeastern/lib/python3.10/site-packages/sklearn/metrics/_classification.py:2955, in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2953 headers = ["precision", "recall", "f1-score", "support"]
#    2954 # compute per-class results without averaging
# -> 2955 p, r, f1, s = precision_recall_fscore_support(
#    2956     y_true,
#    2957     y_pred,
#    2958     labels=labels,
#    2959     average=None,
#    2960     sample_weight=sample_weight,
#    2961     zero_division=zero_division,
#    2962 )
#    2963 rows = zip(target_names, p, r, f1, s)
#    2965 if y_type.startswith("multilabel"):
#
# File ~/anaconda3/envs/northeastern/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File ~/anaconda3/envs/northeastern/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1975, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1973 # Calculate tp_sum, pred_sum, true_sum ###
#    1974 samplewise = average == "samples"
# -> 1975 MCM = multilabel_confusion_matrix(
#    1976     y_true,
#    1977     y_pred,
#    1978     sample_weight=sample_weight,
#    1979     labels=labels,
#    1980     samplewise=samplewise,
#    1981 )
#    1982 tp_sum = MCM[:, 1, 1]
#    1983 pred_sum = tp_sum + MCM[:, 0, 1]
#
# File ~/anaconda3/envs/northeastern/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File ~/anaconda3/envs/northeastern/lib/python3.10/site-packages/sklearn/metrics/_classification.py:686, in multilabel_confusion_matrix(y_true, y_pred, sample_weight, labels, samplewise)
#     680     raise ValueError(
#     681         "Samplewise metrics are not available outside of "
#     682         "multilabel classification."
#     683     )
#     685 le = LabelEncoder()
# --> 686 le.fit(labels)
#     687 y_true = le.transform(y_true)
#     688 y_pred = le.transform(y_pred)
#
# File ~/anaconda3/envs/northeastern/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:94, in LabelEncoder.fit(self, y)
#      81 """Fit label encoder.
#      82
#      83 Parameters
#    (...)
#      91     Fitted label encoder.
#      92 """
#      93 y = column_or_1d(y, warn=True)
# ---> 94 self.classes_ = _unique(y)
#      95 return self
#
# File ~/anaconda3/envs/northeastern/lib/python3.10/site-packages/sklearn/utils/_encode.py:52, in _unique(values, return_inverse, return_counts)
#      21 """Helper function to find unique values with support for python objects.
#      22
#      23 Uses pure python method for object dtype, and numpy method for
#    (...)
#      49     array. Only provided if `return_counts` is True.
#      50 """
#      51 if values.dtype == object:
# ---> 52     return _unique_python(
#      53         values, return_inverse=return_inverse, return_counts=return_counts
#      54     )
#      55 # numerical
#      56 return _unique_np(
#      57     values, return_inverse=return_inverse, return_counts=return_counts
#      58 )
#
# File ~/anaconda3/envs/northeastern/lib/python3.10/site-packages/sklearn/utils/_encode.py:188, in _unique_python(values, return_inverse, return_counts)
#     186 except TypeError:
#     187     types = sorted(t.__qualname__ for t in set(type(v) for v in values))
# --> 188     raise TypeError(
#     189         "Encoders require their input argument must be uniformly "
#     190         f"strings or numbers. Got {types}"
#     191     )
#     192 ret = (uniques,)
#     194 if return_inverse:
#
# TypeError: Encoders require their input argument must be uniformly strings or numbers. Got ['int', 'str']
